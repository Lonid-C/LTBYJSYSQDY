# %%
from pathlib import Path
import os
os.chdir('/content/q3_joint_v1')
print(Path.cwd())
# Out:
# /content/q3_joint_v1

# %%
import subprocess, sys
subprocess.run([sys.executable, 'code/run_joint.py'], check=True)
# Out:
# CompletedProcess(args=['/usr/bin/python3', 'code/run_joint.py'], returncode=0)

# %%
import pandas as pd
from IPython.display import display
display(pd.read_csv('results/comparison.csv'))
display(pd.read_csv('results/joint_error_diagnostics.csv'))
# Out:
#              method    total_cost  adjusted_cost     plan_cost        up_cost  \
# 0  inherited_hybrid  1.331070e+07   1.330790e+07  1.244460e+07  704044.818459
# 1      joint_hybrid  1.328833e+07   1.328553e+07  1.245220e+07  690868.983886
#
#    down_net_cost  emergency_cost  emergency_kwh         up_kwh       down_kwh  \
# 0 -150150.294458   312207.883910   54734.178722  590755.176141  462951.647986
# 1 -149091.058603   294358.713067   52333.990502  583701.672932  461589.712900
#
#      charge_kwh  discharge_kwh     spill_kwh  equivalent_cycles        cvar95  \
# 0  6.736867e+06   5.450746e+06  1.339755e+06         227.114405  62961.231128
# 1  6.745817e+06   5.457991e+06  1.335175e+06         227.416302  63021.044845
#
#       max_daily     daily_std    final_soc
# 0  68195.163391  14049.040650  8316.424319
# 1  68726.455155  14014.909194  8320.908005
#                period  issue_hour      n   pearson  \
# 0    training_january           0   1695  0.048081
# ...

# %%
import subprocess, sys
subprocess.run([sys.executable, 'qa/cache_and_delivery.py'], check=True)
# Out:
# CompletedProcess(args=['/usr/bin/python3', 'qa/cache_and_delivery.py'], returncode=0)
